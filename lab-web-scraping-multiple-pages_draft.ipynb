# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

from time import sleep
from random import randint

import regex as re

# %% [markdown]
# ---
# # lab-web-scraping-single-page
# ---

# %%
# url_vortex = "https://www.popvortex.com/music/charts/top-100-songs.php"
# response_vortex = requests.get(url_vortex)
# response_vortex.status_code

# %%
# soup_vortex = BeautifulSoup(response_vortex.content, 'html.parser')

# %%
# songs_vortex = []

# for title in soup_vortex.select("div.chart-content > p.title-artist > cite"):
#     songs_vortex.append(title.text)

# %%
# songs_vortex

# %%
# artist_vortex = []   
# for artist in soup_vortex.select("div.chart-content > p.title-artist > em"):
#     artist_vortex.append(artist.text)

# %%
# df_vortex = pd.DataFrame({'song':songs_vortex, 'artist':artist_vortex})
# # df_vortex

# %% [markdown]
# ---
# # lab-web-scraping-multiple-pages
# ---

# %%
url = "https://www.listchallenges.com/the-top-1000-billboard-hot-100-songs-of-all-time"
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %% [markdown]
# ### Test1

# %%
# test1 = soup_challenges.select('#repeaterListItems > div:nth-child(1) > div > div.item-name')
# test1

# %%
# for item in row:
#     print(item.text)

# %% [markdown]
# ### Test2

# %%
# test2 = soup_challenges.select('#repeaterListItems')
# test2

# %%
# number = 1
# str_number=str(number)
# string1 = '#repeaterListItems > div:nth-child(' +str_number+ ') > div > div.item-name'
# soup.select(string1)

# %%
# list_challenges = []
# for i in range(1,26):
#     number=i
#     str_number=str(number)
#     string = '#repeaterListItems > div:nth-child(' +str_number+ ') > div > div.item-name'
#     selection=soup_challenges.select(string)
#     list_challenges.append(selection)

# %%
# list_challenges

# %%
# for item in list_challenges[0]:
#     print(item.text)

# %%
# list_challenges2=[]
# for i in range(0,25):
#     for item in list_challenges[i]:
#         print(item.text)

# %%
# list_challenges2=[]
# for i in range(0,25):
#     for item in list_challenges[i]:
#         list_challenges2.append(item.text)

# %%
# list_challenges2

# %%
# list_challenges3 = [item.strip() for item in list_challenges2[0:25]]

# %%
# list_challenges3

# %%
# songs = []
# artists = []

# for element in list2:
#     parts = element.split('-')
#     if len(parts) == 2:
#         song = parts[0].strip()
#         artist = parts[1].strip()
#         songs.append(song)
#         artists.append(artist)
# df2 = pd.DataFrame({'song':songs, 'artist':artists})

# %% [markdown]
# ### Final Code

# %%
list1 = []
for i in range(1,46):
    number=i
    str_number=str(number)
    string = '#repeaterListItems > div:nth-child(' +str_number+ ') > div > div.item-name'
    selection=soup.select(string)
    list1.append(selection)

# %%
list1
# Out:
# [[<div class="item-name">
#                                           The Twist - Chubby Checker
#                                       </div>],
#  [<div class="item-name">
#                                           Smooth - Santana
#                                       </div>],
#  [<div class="item-name">
#                                           MacK the Knife - Bobby Darin
#                                       </div>],
#  [<div class="item-name">
#                                           Mark Ronson, "Uptown Funk" (Feat. Bruno Mars)
#                                       </div>],
#  [],
#  [<div class="item-name">
#                                           Leann Rimes - How Do I Live
#                                       </div>],
#  [<div class="item-name">
#                                           Party Rock Anthem - LMFAO
#                                       </div>],
#  [<div class="item-name">
# ...

# %%
# text1 =list1[0][0].text
# text1

# %%
# list1[0][0]

# %%
# list1[0]

# %%
# type(list1[0])

# %%
# type(list1[0][0])

# %%
# list1[0][0].get_text()

# %%
# type(text1)

# %%
# list1[0][0]["class"]

# %%
# title = re.findall(r'(\b[\w ]+ - )', text1)

# %%
# title

# %%
# type(title)

# %%
# title2 = title.extract(r'([\w ]+)')

# %%
list2=[]
for i in range(0,45):
    for item in list1[i]:
        list2.append(item.text)

# %%
len(list2)
# Out:
# 40

# %%
# df1 = pd.DataFrame({'column1':list2})

# %%
# df1.shape

# %%
list3 = [item.strip() for item in list2[0:45]]

# %%
len(list3)
# Out:
# 40

# %%
list3
# Out:
# ['The Twist - Chubby Checker',
#  'Smooth - Santana',
#  'MacK the Knife - Bobby Darin',
#  'Mark Ronson, "Uptown Funk" (Feat. Bruno Mars)',
#  'Leann Rimes - How Do I Live',
#  'Party Rock Anthem - LMFAO',
#  'Black Eyed Peas - I Gotta Feeling',
#  'Macarena (Bayside Boys Mix) - Los Del Rio',
#  'Shape of You - Ed Sheeran',
#  'Physical (Olivia Newton John)',
#  'Debby Boone - You Light Up My Life',
#  'Hey Jude - The Beatles',
#  'Closer - The Chainsmokers Ft. Hasley',
#  'We Belong Together - Mariah Carey',
#  'Old Town Road (Remix) - Lil Nas X Ft. Billy Ray Cyrus',
#  'Toni Braxton - Un-Break My Heart',
#  'Usher - Yeah! (Featuring Lil Jon and Ludacris)',
#  'Bette Davis Eyes - Kim Carnes',
#  'Girls Like You - Maroon 5, Cardi B',
#  'Endless Love - Diana Ross and Lionel Richie',
#  "Rod Stewart - Tonight's the Night",
#  'Foolish Games - Jewel',
#  'Circles - Post Malone',
#  '(Everything I Do) I Do It for You - Bryan Adams',
#  "I'll Make Love to You - Boyz II Men",
# ...

# %%
songs = []
artists = []

for element in list3:
    parts = element.split(' - ')
    if len(parts) == 2:
        song = parts[0].strip()
        artist = parts[1].strip()
        songs.append(song)
        artists.append(artist)
df2 = pd.DataFrame({'song':songs, 'artist':artists})

# %%
songs = []
artists = []

for element in list3:
        song = parts[0].strip()
        artist = parts[1].strip()
        songs.append(song)
        artists.append(artist)
df2 = pd.DataFrame({'song':songs, 'artist':artists})

# %%
df2
# Out:
#                                              song  \
# 0                                       The Twist
# 1                                          Smooth
# 2                                  MacK the Knife
# 3                                     Leann Rimes
# 4                               Party Rock Anthem
# 5                                 Black Eyed Peas
# 6                     Macarena (Bayside Boys Mix)
# 7                                    Shape of You
# 8                                     Debby Boone
# 9                                        Hey Jude
# 10                                         Closer
# 11                             We Belong Together
# 12                          Old Town Road (Remix)
# 13                                   Toni Braxton
# 14                                          Usher
# 15                               Bette Davis Eyes
# 16                                 Girls Like You
# 17                                   Endless Love
# ...

# %% [markdown]
# I can´t extract all of them because some have this pattern: 'Mark Ronson, "Uptown Funk" (Feat. Bruno Mars)'

# %% [markdown]
# # Iterations

# %%
iterations = range(0, 25)

pages = []

for i in iterations:
    start_at= str(i)
    url = "https://www.listchallenges.com/the-top-1000-billboard-hot-100-songs-of-all-time/list/" + start_at

    response = requests.get(url, headers = {"Accept-Language": "en-US"})

    # monitor the process by printing the status code
    print("Status code: " + str(response.status_code))

    # store response into "pages" list
    pages.append(response)

    # respectful nap:
    wait_time = randint(1,4000)
    print("I will sleep for " + str(wait_time/1000) + " second/s.")
    sleep(wait_time/1000)
# Out:
# Status code: 200
# I will sleep for 0.5 second/s.
# Status code: 200
# I will sleep for 0.436 second/s.
# Status code: 200
# I will sleep for 2.049 second/s.
# Status code: 200
# I will sleep for 3.916 second/s.
# Status code: 200
# I will sleep for 3.622 second/s.
# Status code: 200
# I will sleep for 0.663 second/s.
# Status code: 200
# I will sleep for 1.985 second/s.
# Status code: 200
# I will sleep for 3.818 second/s.
# Status code: 200
# I will sleep for 1.504 second/s.
# Status code: 200
# I will sleep for 0.084 second/s.
# Status code: 200
# I will sleep for 0.593 second/s.
# Status code: 200
# I will sleep for 2.472 second/s.
# Status code: 200
# I will sleep for 0.429 second/s.
# Status code: 200
# I will sleep for 3.001 second/s.
# Status code: 200
# I will sleep for 3.157 second/s.
# Status code: 200
# I will sleep for 0.87 second/s.
# Status code: 200
# I will sleep for 2.066 second/s.
# Status code: 200
# I will sleep for 1.366 second/s.
# Status code: 200
# ...

# %%
list1 = []

for i in range(len(pages)):
    soup = BeautifulSoup(pages[i].content, "html.parser")

    for j in range(1,46):
        number=j
        str_number=str(number)
        string = '#repeaterListItems > div:nth-child(' +str_number+ ') > div > div.item-name'
        selection=soup.select(string)
        list1.append(selection)

# %%
list2=[]

for k in range(0,1125):
    for item in list1[k]:
        list2.append(item.text)

# %%
list2
# Out:
# ['\r\n                                        The Twist - Chubby Checker\r\n                                    ',
#  '\r\n                                        Smooth - Santana\r\n                                    ',
#  '\r\n                                        MacK the Knife - Bobby Darin\r\n                                    ',
#  '\r\n                                        Mark Ronson, "Uptown Funk" (Feat. Bruno Mars)\r\n                                    ',
#  '\r\n                                        Leann Rimes - How Do I Live\r\n                                    ',
#  '\r\n                                        Party Rock Anthem - LMFAO\r\n                                    ',
#  '\r\n                                        Black Eyed Peas - I Gotta Feeling\r\n                                    ',
#  '\r\n                                        Macarena (Bayside Boys Mix) - Los Del Rio\r\n                                    ',
# ...

# %%
list3 = [item.strip() for item in list2[0:1000]]

# %%
songs = []
artists = []
for element in list3:
    parts = element.split(' - ')
    if len(parts) == 2:
        song = parts[0].strip()
        artist = parts[1].strip()
        songs.append(song)
        artists.append(artist)
            
df2 = pd.DataFrame({'song':songs, 'artist':artists})

# %% [markdown]
# ### Retrieve an arbitrary Wikipedia page of "Python" and create a list of links on that page: url ='https://en.wikipedia.org/wiki/Python'

# %%
url='https://en.wikipedia.org/wiki/Python'
response=requests.get(url)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(url, 'html.parser')

# %%
soup.select("a")
# Out:
# []

# %%
soup.title

# %%
soup.find_all("a")
# Out:
# []

# %%
soup.select("#mw-content-text > div.mw-parser-output > ul:nth-child(7) > li:nth-child(1) > a")
# Out:
# []

# %%
soup.select('#mw-content-text > div.mw-parser-output > ul:nth-child(7) > li:nth-child(1)')
# Out:
# []

# %%
#mw-content-text > div.mw-parser-output > ul:nth-child(7) > li:nth-child(1) > a
